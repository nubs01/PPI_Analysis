# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import easygui as eg
from ppi_analysis import *

# %%
data_files = eg.fileopenbox(multiple=True,msg='Select all PPI data files')

# %%
data = pd.DataFrame()
Nnan = 0
for file in data_files:
    tmp = import_ppi_data(file)
    Nnan = Nnan + data.isnull().any(axis=1).sum()
    tmp = tmp.dropna()
    data = data.append(tmp)
data.reset_index(inplace=True,drop=True)

# %%
data['Gender'],data['Genotype'] = zip(*data['Group'].map(parse_group))
data = parse_session_and_trial(data)

# %%
data.head()
# Out:
#    Chamber Subject            Session  Channel       Trial  Trial Num  \
# 0        1   LDF74   181212_LDF74_ACC        1  NoStim_0_0          1
# 1        1   LDF74  181212_LDF74_ACC2        1  NoStim_0_0          1
# 2        1   LDF74   181213_LDF74_ACC        1  NoStim_0_0          1
# 3        1   LDF74  181213_LDF74_ACC2        1  NoStim_0_0          1
# 4        1   LDF74   181214_LDF74_ACC        1  NoStim_0_0          1
#
#      Group  Trial List Block  Samples  Rate     ...      \
# 0  ACC_MDF                 1      200  1000     ...
# 1  ACC_MDF                 1      200  1000     ...
# 2  ACC_MDF                 1      200  1000     ...
# 3  ACC_MDF                 1      200  1000     ...
# 4  ACC_MDF                 1      200  1000     ...
#
#                  Run Time  TimeStamp  Gender  Genotype    Date  Animal  \
# 0   12/12/2018 2:25:45 PM        0.0       M        DF  181212   LDF74
# 1   12/12/2018 2:44:13 PM        0.0       M        DF  181212   LDF74
# ...

# %%
# grab rPPI data
ppiData = data.query('Session_Type=="rPPi"')

# %%
ppiData["% PPI"] = np.nan
ppiData['% PPI'] = ppiData.apply(lambda x: calcPPI(x,ppiData),axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/.local/lib/python3.5/site-packages/pandas/core/frame.py in _ensure_valid_index(self, value)
#    3172             try:
# -> 3173                 value = Series(value)
#    3174             except:
#
# ~/.local/lib/python3.5/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     276
# --> 277                 data = SingleBlockManager(data, index, fastpath=True)
#     278
#
# ~/.local/lib/python3.5/site-packages/pandas/core/internals.py in __init__(self, block, axis, do_integrity_check, fastpath)
#    4676         if not isinstance(block, Block):
# -> 4677             block = make_block(block, placement=slice(0, len(axis)), ndim=1)
#    4678
#
# ~/.local/lib/python3.5/site-packages/pandas/core/internals.py in make_block(values, placement, klass, ndim, dtype, fastpath)
#    3204
# ...
